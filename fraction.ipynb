# %% [markdown]
# <a href="https://colab.research.google.com/github/jackp2733/cs417-exercises/blob/main/fraction.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
class Fraction:
    def __init__(self, top, bottom):
        self.num = top
        self.den = bottom

    def __str__(self):
        return f"{self.num}/{self.den}"

    def __add__(self, other):
        new_num = self.num * other.den + self.den * other.num
        new_den = self.den * other.den
        return Fraction(new_num, new_den)

    def __sub__(self, other):
        new_num = self.num * other.den - self.den * other.num
        new_den = self.den * other.den
        return Fraction(new_num, new_den)

    def __mul__(self, other):
        return Fraction(self.num * other.num, self.den * other.den)

    def __truediv__(self, other):
        return Fraction(self.num * other.den, self.den * other.num)

f1 = Fraction(3, 4)
f2 = Fraction(4, 5)

print("Fractions:")
print(f"f1 = {f1}")
print(f"f2 = {f2}")

result_add = f1 + f2
print(f"\nAddition: {f1} + {f2} = {result_add}")

result_mul = f1 * f2
print(f"Multiplication: {f1} * {f2} = {result_mul}")

result_sub = f1 - f2
print(f"Subtraction: {f1} - {f2} = {result_sub}")

result_div = f1 / f2
print(f"Division: {f1} / {f2} = {result_div}")
# Out:
# Fractions:
# f1 = 3/4
# f2 = 4/5
#
# Addition: 3/4 + 4/5 = 31/20
# Multiplication: 3/4 * 4/5 = 12/20
# Subtraction: 3/4 - 4/5 = -1/20
# Division: 3/4 / 4/5 = 15/16
